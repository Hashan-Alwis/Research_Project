# %%
import pandas as pd
import random 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n = pd.read_csv("Restaurants.csv")

# %%
df = n["Address"]

# %%
n = pd.concat([n, n], axis=0, ignore_index=True)

# %%
n
# Out:
#                               Name  \
# 0         BAVARIAN BARN RESTAURANT
# 1                 LORDS RESTAURANT
# 2            NIHONBASHI RESTAURANT
# 3       FREE WIND RESTAURANT & BAR
# 4                 EDWIN RESTAURANT
# ..                             ...
# 947  SHAN CITY CHINEESE RESTAURANT
# 948     CHINESE DELIGHT RESTAURANT
# 949      SAMEEHA FAMILY RESTAURANT
# 950            SEA PORT RESTAURANT
# 951                        AMUSEUM
#
#                                                Address Grade     District  \
# 0                  NO. 11, GALLE FACE COURT 02 COLOMBO     A      Colombo
# 1                 80B PORUTHOTA ROAD ETTHUKALA NEGOMBO     A      Gampaha
# 2                NO 11, GALLE FACE TERRACE, COLOMBO 03     A      Colombo
# 3       NO 1285, KANDY ROAD, PALAIYOOTHU, TRINCO MALEE     A  Trincomalee
# 4                            204, LEWIS PLACE, NEGOMBO     B      Gampaha
# ..                                                 ...   ...          ...
# ...

# %%
# Shuffle the DataFrame
n = n.sample(frac=1, random_state=42).reset_index(drop=True)

# Display the shuffled Data

# %%
import pandas as pd
import random
import string

# Example DataFrame


# Function to generate a random unique ID of length 8
def generate_unique_id(existing_ids, length=8):
    while True:
        unique_id = ''.join(random.choices(string.ascii_uppercase + string.digits, k=length))
        if unique_id not in existing_ids:  # Ensure uniqueness
            return unique_id

# Create a set to track existing IDs
existing_ids = set()

# Add a new column with unique IDs
n['UserID'] = [generate_unique_id(existing_ids) for _ in range(len(n))]
existing_ids.update(n['UserID'])

# %%
df= n[["UserID", "Address"]]

# %%
df
# Out:
#        UserID                                            Address
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 947  KAY8DJ9B             ELLA JUNCTION,HAPUTHALE ROAD,WELLAWAYA
# 948  JRMCPVGO   NO.270/2,KADUWELA ROAD,THALANGAMA NORTH,KOSWATTA
# 949  EJ8J32D9  SHOP NO- GF 07,DUTCH HOSPITAL SHOPPING PRECINT...
# 950  5U6L6JJ4               G05, OLD DUTCH HOSPITAL, FORT, GALLE
# 951  0E24LDGY       AKKARAWATTA, NABETA, MELSIRIPURA, KURUNEGALA
#
# [952 rows x 2 columns]

# %%
categories = ['low level', 'low-mid level', 'mid-high level', 'mid level', 'high level']

# Assign categories equally
df['Category'] = [categories[i % len(categories)] for i in range(len(df))]
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\628602083.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category'] = [categories[i % len(categories)] for i in range(len(df))]

# %%
indices_to_update=df[df["Category"]=="high level"][20:35]["Category"].index

# %%
df.loc[indices_to_update, 'Category'] = 'low level'

# %%
df["Category"].value_counts()
# Out:
# Category
# low level         206
# low-mid level     191
# mid-high level    190
# mid level         190
# high level        175
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (952, 3)

# %%
old = df[800:]
old.shape
# Out:
# (152, 3)

# %%
df =df[:800]

# %%
x = df.copy()

# %%
df.rename(columns={'Category': 'category'}, inplace=True)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\1405507135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Category': 'category'}, inplace=True)

# %%
df
# Out:
#        UserID                                            address  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10
#
#            category
# 0         low level
# 1     low-mid level
# 2    mid-high level
# 3         mid level
# 4        high level
# ..              ...
# 795       low level
# ...

# %%
import pandas as pd
import numpy as np

# Define the categories and age ranges with probabilities
age_distribution = {
    'low level': [(18, 23, 1.0)],  # 100% in 18-23 range
    'low-mid level': [(20, 25, 0.8), (25, 28, 0.2)],
    'mid level': [(28, 32, 0.9), (32, 35, 0.1)],
    'mid-high level': [(32, 35, 0.4), (35, 45, 0.4), (45, 55, 0.2)],
    'high level': [(30, 40, 0.4), (40, 55, 0.6)],
}

# Function to generate a random age based on the category's distribution
def generate_age(category):
    ranges = age_distribution[category]
    # Separate the age ranges and probabilities
    age_ranges = [r[0:2] for r in ranges]
    probabilities = [r[2] for r in ranges]
    
    # Choose a range based on probabilities
    chosen_range = np.random.choice(len(age_ranges), p=probabilities)
    
    # Get the chosen age range
    min_age, max_age = age_ranges[chosen_range]
    
    # Generate a random age within the chosen range
    return np.random.randint(min_age, max_age + 1)

# Example DataFrame


# Add the age column
df['age'] = df['category'].apply(generate_age)

# print(df)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\4264548405.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'] = df['category'].apply(generate_age)

# %%
df
# Out:
#        UserID                                            address  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10
#
#            category  age
# 0         low level   21
# 1     low-mid level   22
# 2    mid-high level   32
# 3         mid level   31
# 4        high level   50
# ..              ...  ...
# ...

# %%
import pandas as pd
import numpy as np

# Define the categories, positions, and age-based probabilities
category_positions = {
    'low level': ['Intern', 'Trainee', 'Junior Developer'],
    'low-mid level': ['Junior Developer', 'Junior Engineer', 'Associate Engineer'],
    'mid level': ['Associate Engineer', 'Software Engineer'],
    'mid-high level': ['Software Engineer', 'Senior Engineer', 'Tech Lead'],
    'high level': ['Senior Engineer', 'Tech Lead', 'Architect', 'Principal Engineer']
}

# Age-based probability distribution for each position
age_position_probability = {
    'low level': {
        (18, 23): {'Intern': 0.8, 'Trainee': 0.2, 'Junior Developer': 0.0},
    },
    'low-mid level': {
        (20, 25): {'Junior Developer': 0.5, 'Junior Engineer': 0.3, 'Associate Engineer': 0.2},
        (25, 28): {'Junior Developer': 0.3, 'Junior Engineer': 0.4, 'Associate Engineer': 0.3},
    },
    'mid level': {
        (26, 30): {'Associate Engineer': 0.4, 'Software Engineer': 0.6},
        (30, 32): {'Associate Engineer': 0.3, 'Software Engineer': 0.7},
    },
    'mid-high level': {
        (32, 35): {'Software Engineer': 0.3, 'Senior Engineer': 0.4, 'Tech Lead': 0.3},
        (35, 45): {'Senior Engineer': 0.5, 'Tech Lead': 0.3, 'Software Engineer': 0.2},
        (45, 55): {'Senior Engineer': 0.4, 'Tech Lead': 0.3, 'Software Engineer': 0.3},
    },
    'high level': {
        (30, 40): {'Senior Engineer': 0.3, 'Tech Lead': 0.4, 'Architect': 0.2, 'Principal Engineer': 0.1},
        (40, 55): {'Senior Engineer': 0.4, 'Tech Lead': 0.4, 'Architect': 0.1, 'Principal Engineer': 0.1},
    }
}

# Function to generate a random applying position based on category and age
def get_applying_position(category, age):
    # Choose position based on category
    positions = category_positions[category]
    
    if category in age_position_probability:
        # Find the age range that the person's age falls into
        age_ranges = age_position_probability[category]
        
        # Select the correct range based on age
        for (min_age, max_age), prob_dist in age_ranges.items():
            if min_age <= age <= max_age:
                # We have found the correct age range, now choose a position based on the probabilities
                if np.random.rand() < 0.5:  # 70% chance to consider age-based probabilities
                    # Select a position based on the age-specific probability distribution
                    chosen_position = np.random.choice(positions, p=[prob_dist.get(pos, 0) for pos in positions])
                    return chosen_position
                else:
                    # 30% chance to choose a random position based only on category
                    return np.random.choice(positions)

    # If no age-based probabilities, choose a random position based on category
    return np.random.choice(positions)

# Example DataFrame with category and age
# data = {'category': ['low level', 'low-mid level', 'mid level', 'mid-high level', 'high level'],
#         'age': [22, 26, 30, 40, 45]}  # Example ages
# df = pd.DataFrame(data)

# Add the "applying position" column based on both category and age
df['applying position'] = df.apply(lambda row: get_applying_position(row['category'], row['age']), axis=1)

# print(df)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\2149551712.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['applying position'] = df.apply(lambda row: get_applying_position(row['category'], row['age']), axis=1)

# %%
df
# Out:
#        UserID                                            address  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10
#
#            category  age   applying position
# 0         low level   21             Trainee
# 1     low-mid level   22    Junior Developer
# 2    mid-high level   32     Senior Engineer
# ...

# %%
df["category"].unique()
# Out:
# array(['low level', 'low-mid level', 'mid-high level', 'mid level',
#        'high level'], dtype=object)

# %%
# Define experience mapping for positions
# experience_map = {
#     'Intern': ['No experience', 'Below 1 year'],
#     'Trainee': ['No experience', 'Below 1 year'],
#     'Junior Developer': ['1-2 years'],
#     'Junior Engineer': ['1-2 years', '2-5 years'],
#     'Associate Engineer': ['1-2 years', '2-5 years'],
#     'Software Engineer': ['2-5 years', '5-10 years', '10+ years'],
#     'Senior Engineer': ['2-5 years', '5-10 years', '10+ years'],
#     'Tech Lead': ['5-10 years', '10+ years'],
#     'Architect': ['5-10 years', '10+ years'],
#     'Principal Engineer': ['5-10 years', '10+ years']
# }

experience_map = {
    'low level': ['No experience', 'Below 1 year'],
    'low-mid level': [ '1-2 years'],
    'mid level': ['1-2 years','2-5 years'],
    'mid-high level': [ '5-10 years'],
    'high level': ['5-10 years', '10+ years']
}




# Function to assign experience based on position
def assign_experience(position):
    return random.choice(experience_map[position])  # Randomly pick an experience level for the position

# Add Experience column to the DataFrame
df['experience'] = df['category'].apply(assign_experience)

# Display the updated DataFrame
# print(df)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\499670954.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['experience'] = df['category'].apply(assign_experience)

# %%
df
# Out:
#        UserID                                            address  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10
#
#            category  age   applying position    experience
# 0         low level   21             Trainee  Below 1 year
# 1     low-mid level   22    Junior Developer     1-2 years
# ...

# %%
df["applying position"].unique()
# Out:
# array(['Trainee', 'Junior Developer', 'Senior Engineer',
#        'Associate Engineer', 'Intern', 'Junior Engineer',
#        'Software Engineer', 'Principal Engineer', 'Tech Lead',
#        'Architect'], dtype=object)

# %%
def get_leadership_experience(position):
    if position in ['low level']:
        return 'no experience'
    elif position in ['high level', 'mid-high level']:
        return '5 years+ experience'
    else:
        # Randomly assign one of the other experience categories
        return np.random.choice(['1-2 years experience', '2-5 years experience'])

# %%
df['leadership experience'] = df['category'].apply(get_leadership_experience)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\854523866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['leadership experience'] = df['category'].apply(get_leadership_experience)

# %%
df
# Out:
#        UserID                                            address  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10
#
#            category  age   applying position    experience  \
# 0         low level   21             Trainee  Below 1 year
# 1     low-mid level   22    Junior Developer     1-2 years
# ...

# %%
df["category"].unique()
# Out:
# array(['low level', 'low-mid level', 'mid-high level', 'mid level',
#        'high level'], dtype=object)

# %%
def get_english_proficiency(position):
    if position in ['high level', 'mid-high level', 'mid level']:
        return 'Fluent'
    elif position in ['low level', 'low-mid level']:
        return np.random.choice(['Intermediate', 'Beginner', 'Fluent'])

# %%
# df.drop("english proficiency", axis=1, inplace=True)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\2547907618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("english proficiency", axis=1, inplace=True)

# %%
df['english proficiency'] = df['category'].apply(get_english_proficiency)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\242627184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['english proficiency'] = df['category'].apply(get_english_proficiency)

# %%
df["applying position"].unique()
# Out:
# array(['Trainee', 'Junior Developer', 'Senior Engineer',
#        'Associate Engineer', 'Intern', 'Junior Engineer',
#        'Software Engineer', 'Principal Engineer', 'Tech Lead',
#        'Architect'], dtype=object)

# %%
# salary_ranges = {
#     'Intern': (30000, 50000),
#     'Junior Developer': (50000, 80000),
#     'Software Engineer': (80000, 120000),
#     'Senior Engineer': (120000, 180000),
#     'Trainee': (30000, 50000),
#     'Junior Engineer': (50000, 80000),
#     'Associate Engineer': (70000, 100000),
#     'Tech Lead': (150000, 250000),
#     'Principal Engineer': (200000, 300000),
#     'Architect': (250000, 400000)
# }

salary_ranges = {
    'low level': (30000, 50000),
    'low-mid level': (50000, 80000),
    'mid level': (120000, 200000),
    'mid-high level': (200000, 500000),
    'high level': (500000, 1000000)
}

def generate_salary(position):
    min_salary, max_salary = salary_ranges[position]
    # Generate a random value within the range and round it to the nearest 1000
    salary = random.randint(min_salary // 10000, max_salary // 10000) * 10000
    return salary

df['salary expectation'] = df['category'].apply(generate_salary)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\3102589076.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['salary expectation'] = df['category'].apply(generate_salary)

# %%
df
# Out:
#        UserID                                            address  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10
#
#            category  age   applying position    experience  \
# 0         low level   21             Trainee  Below 1 year
# 1     low-mid level   22    Junior Developer     1-2 years
# ...

# %%
# df.drop("salary expectation", axis=1, inplace=True)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\3419755578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("salary expectation", axis=1, inplace=True)

# %%
import pandas as pd
import random

# Sample DataFrame with applying position and category columns
# df = pd.DataFrame({
#     'applying position': ['Intern', 'Junior Developer', 'Software Engineer', 
#                           'Senior Engineer', 'Trainee', 'Junior Engineer', 
#                           'Associate Engineer', 'Tech Lead', 'Principal Engineer', 'Architect'],
#     'category': ['low level', 'low-mid level', 'mid level', 'mid-high level', 'low level', 'low-mid level', 
#                  'mid level', 'mid-high level', 'high level', 'high level']
# })

# Function to generate gender based on applying position and category
def generate_gender(row):
    position = row['applying position']
    category = row['category']
    
    # Define the probability of male based on category and position
    if category in ['high level', 'mid-high level'] or position in ['Senior Engineer', 'Tech Lead', 'Principal Engineer', 'Architect']:
        # 90% chance of male for senior/high level positions
        return 'Male' if random.random() < 0.9 else 'Female'
    else:
        # 70% chance of male for others
        return 'Male' if random.random() < 0.7 else 'Female'

# Add the gender column to the DataFrame
df['gender'] = df.apply(generate_gender, axis=1)

# print(df)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_8856\1034935557.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df.apply(generate_gender, axis=1)

# %%
old
# Out:
#        UserID                                            Address  \
# 800  CWNWC40B                 NO. 08, SEAVIEW AVENUE, COLOMBO 03
# 801  KQPCWFCJ                  GALLE ROAD,KALUWAMODARA,ALUTHGAMA
# 802  XVSTJ9H9         NO. 20/3, ABDUL GAFFOR MAWATHA, COLOMBO 03
# 803  LGPP4T1V        NO. 571, GALLE ROAD, RAWATHAWATTA, MORATUWA
# 804  X7KMOMIL           NO.90,S.DE.S.JAYASINGHA MAWATHA,KOHUWALA
# ..        ...                                                ...
# 947  KAY8DJ9B             ELLA JUNCTION,HAPUTHALE ROAD,WELLAWAYA
# 948  JRMCPVGO   NO.270/2,KADUWELA ROAD,THALANGAMA NORTH,KOSWATTA
# 949  EJ8J32D9  SHOP NO- GF 07,DUTCH HOSPITAL SHOPPING PRECINT...
# 950  5U6L6JJ4               G05, OLD DUTCH HOSPITAL, FORT, GALLE
# 951  0E24LDGY       AKKARAWATTA, NABETA, MELSIRIPURA, KURUNEGALA
#
#            Category
# 800       low level
# 801   low-mid level
# 802  mid-high level
# 803       mid level
# 804      high level
# ..              ...
# 947  mid-high level
# ...

# %%
df
# Out:
#        UserID                                            address  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA
# ..        ...                                                ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10
#
#            category  age   applying position    experience  \
# 0         low level   21             Trainee  Below 1 year
# 1     low-mid level   22    Junior Developer     1-2 years
# ...

# %%
old
# Out:
#        UserID                                            Address  \
# 800  WX1JZCR2                         505,UNION PLACE,COLOMBO 02
# 801  33MH5PPI  NO. 673/1, KANDY ROAD, PELIYAGODA, PATTIYA JUN...
# 802  GSDTWX10                   NO. 245, MALWARUSHAWA, DEHIOWITA
# 803  ASAKFFWW                    335, DANDAGAMUWA , KULIYAPITIYA
# 804  TG8P6T7P         NO:538/2,538/1,WEWALA,GALLE ROAD,HIKKADUWA
# ..        ...                                                ...
# 947  5M814RA2                 154/A,KANDY ROAD,DALUGAMA,KELANIYA
# 948  FLFAPFA4        SRI JAYAWARDENAPURA ROAD, DELDUWA, WADDUWA.
# 949  4T4XLV7Q                             40, KANDY ROAD,GAMPOLA
# 950  HYE148BJ               NATIONAL ZOOLOGICAL GARDEN ,DEHIWALA
# 951  P0J96IFO                       39A,HORTON PLACE, COLOMBO 07
#
#            Category
# 800       low level
# 801   low-mid level
# 802  mid-high level
# 803       mid level
# 804      high level
# ..              ...
# 947  mid-high level
# ...

# %%
result = pd.concat([df, old], axis=0, ignore_index=True)

# %%
old.rename(columns={'Address': 'address'}, inplace=True)
# Out:
# C:\Users\Hashan\AppData\Local\Temp\ipykernel_10940\3189981193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old.rename(columns={'Address': 'address'}, inplace=True)

# %%
def fill_nulls_with_random(df):
    """
    Fill NaN values in a DataFrame with random values from the same column.

    Parameters:
    df (pd.DataFrame): Input DataFrame with potential NaN values.

    Returns:
    pd.DataFrame: DataFrame with NaN values filled.
    """
    filled_df = df.copy()  # Create a copy to avoid modifying the original DataFrame

    for column in filled_df.columns:
        if filled_df[column].isnull().any():  # Check if the column has NaN values
            # Get the non-null values for the column
            non_null_values = filled_df[column].dropna()
            
            # Replace NaN values with random choice from the non-null values
            filled_df[column] = filled_df[column].apply(
                lambda x: np.random.choice(non_null_values) if pd.isnull(x) else x
            )

    return filled_df

# %%
new= fill_nulls_with_random(result)
new
# Out:
#        UserID                                           address  \
# 0    XU4121T2            NO:322,KANDY ROAD,AMBEPUSSA,WARAKAPOLA
# 1    Z82B6RAM                 NO. 95, KING STREET, MATALE 21000
# 2    GT5QMRSD  NO. 50, SRI JAYAWARDENAPURA MAWATHA, RAJAGIRIYA.
# 3    N014N2GH       68,W.A SILVA MAWATHA, WELLAWATTE,COLOMBO 06
# 4    8HTLTX97        NO. 436/73, ELVITIGALA MAWATHA, COLOMBO 05
# ..        ...                                               ...
# 947  5M814RA2                154/A,KANDY ROAD,DALUGAMA,KELANIYA
# 948  FLFAPFA4       SRI JAYAWARDENAPURA ROAD, DELDUWA, WADDUWA.
# 949  4T4XLV7Q                            40, KANDY ROAD,GAMPOLA
# 950  HYE148BJ              NATIONAL ZOOLOGICAL GARDEN ,DEHIWALA
# 951  P0J96IFO                      39A,HORTON PLACE, COLOMBO 07
#
#            category   age  applying position     experience  \
# 0         low level  21.0             Intern  No experience
# 1     low-mid level  23.0   Junior Developer      1-2 years
# ...

# %%
new = new.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
new
# Out:
#        UserID                                            address  \
# 0    BKCY3H5Q                               AMBEPUSSA,WARAKAPOLA
# 1    RU41M25E                    5/1,21ST LANE, ISURUPURA,MALABE
# 2    4CSR9D25                       NO. 192, GALLE ROAD, BENTOTA
# 3    HBFWPTA8                     ETHUKALE,PORUTOTA ROAD,NEGOMBO
# 4    MS9M1Q9G                NO. 88/1, WELIPENNA ROAD, ALUTHGAMA
# ..        ...                                                ...
# 947  JDC4CGDH            KOMBAVIL,W.N.4,PUTHUKUDIYUPPU,MULAITIVU
# 948  D4NHPJ7O                     NO. 695 , KANDY ROAD, KELANIYA
# 949  N3EK5540  NO. 19/1A, DAISY VILLA AVENUE.,DUPLICATION ROA...
# 950  WXAY07BG                     CHRISTOPER MAWATHA,WENNAPPUWA.
# 951  ABQC8PFO                       16/2,SCHOFIELD PLACE,COLOMBO
#
#           category   age   applying position    experience  \
# 0        mid level  18.0              Intern     2-5 years
# 1    low-mid level  27.0     Junior Engineer     2-5 years
# ...

# %%
new.columns
# Out:
# Index(['UserID', 'address', 'category', 'age', 'applying position',
#        'experience', 'leadership experience', 'english proficiency',
#        'salary expectation', 'gender'],
#       dtype='object')

# %%
new = new[['UserID', 'address', 'age', 'applying position',
       'experience', 'leadership experience', 'english proficiency',
       'salary expectation', 'gender', 'category']]

# %%
df.to_csv("dataset.csv", index=False)

# %%
df.columns
# Out:
# Index(['UserID', 'address', 'category', 'age', 'applying position',
#        'experience', 'leadership experience', 'salary expectation',
#        'english proficiency', 'gender'],
#       dtype='object')

# %%
df=df[['UserID', 'address', 'age', 'applying position',
       'experience', 'leadership experience', 'english proficiency',
       'salary expectation', 'gender', 'category']]

# %%
result
# Out:
#        UserID                                           address  \
# 0    XU4121T2            NO:322,KANDY ROAD,AMBEPUSSA,WARAKAPOLA
# 1    Z82B6RAM                 NO. 95, KING STREET, MATALE 21000
# 2    GT5QMRSD  NO. 50, SRI JAYAWARDENAPURA MAWATHA, RAJAGIRIYA.
# 3    N014N2GH       68,W.A SILVA MAWATHA, WELLAWATTE,COLOMBO 06
# 4    8HTLTX97        NO. 436/73, ELVITIGALA MAWATHA, COLOMBO 05
# ..        ...                                               ...
# 947  5M814RA2                154/A,KANDY ROAD,DALUGAMA,KELANIYA
# 948  FLFAPFA4       SRI JAYAWARDENAPURA ROAD, DELDUWA, WADDUWA.
# 949  4T4XLV7Q                            40, KANDY ROAD,GAMPOLA
# 950  HYE148BJ              NATIONAL ZOOLOGICAL GARDEN ,DEHIWALA
# 951  P0J96IFO                      39A,HORTON PLACE, COLOMBO 07
#
#            category   age  applying position     experience  \
# 0         low level  21.0             Intern  No experience
# 1     low-mid level  23.0   Junior Developer      1-2 years
# ...

# %%
d1 = pd.read_csv("dataset.csv")
d1
# Out:
#        UserID                                            address  age  \
# 0    GSG0EAXT                  NO. 90, GALLE ROAD, MOUNT LAVINIA   21
# 1    0W96UDHS  NO. 08, GRAND STAND RACE COURSE, REID AVENUE, ...   22
# 2    H3QKDUZ1     NO. 38/F, D.R. WIJEWARDANA MAWATHA, COLOMBO 10   32
# 3    FOYA4EOG                              PINNAWALA, RAMBUKKANA   31
# 4    KSEI5T2V                             PINNAWALA , RAMBUKKANA   50
# ..        ...                                                ...  ...
# 795  Z457GI2Z              43-2/1, MAITLAND CRESCENT,COLOMBO 07.   19
# 796  U166HWBT                     NO. 298, GALLE ROAD, ALUTHGAMA   25
# 797  WLCZLMYK                    NO 266A, MANAMPITA, THALGASWALA   50
# 798  BJFBVDK6             NO.26,KANDY ROAD,KIRIBATHGODA,KELANIYA   29
# 799  MRFQW668                    N0. 464, DEANS ROAD, COLOMBO 10   46
#
#       applying position    experience leadership experience  \
# 0               Trainee  Below 1 year         no experience
# ...

# %%
d2= pd.read_csv("dataset2.csv")
d2
# Out:
#        UserID                                           address  age  \
# 0    XU4121T2            NO:322,KANDY ROAD,AMBEPUSSA,WARAKAPOLA   21
# 1    Z82B6RAM                 NO. 95, KING STREET, MATALE 21000   23
# 2    GT5QMRSD  NO. 50, SRI JAYAWARDENAPURA MAWATHA, RAJAGIRIYA.   40
# 3    N014N2GH       68,W.A SILVA MAWATHA, WELLAWATTE,COLOMBO 06   30
# 4    8HTLTX97        NO. 436/73, ELVITIGALA MAWATHA, COLOMBO 05   47
# ..        ...                                               ...  ...
# 795  8GOOXOAU              630.PRINCE OF WALES AVENUE,COLOMBO14   19
# 796  09OPBJ1G                27A,ANAGARIKA DHARMAPALA MW,KANDY.   22
# 797  JFKU1JR4                           78 MAIN ROAD,KALPITIYA,   42
# 798  76HR7XZI                              WAULAGODA, HIKKADUWA   29
# 799  0RNM7F1D                   NO.28/1,HORTON PLACE,COLOMBO 07   54
#
#       applying position     experience leadership experience  \
# 0                Intern  No experience         no experience
# ...

# %%
df_concat = pd.concat([d1, d2], axis=0, ignore_index=True)

# %%
df_concat.to_csv("data.csv", index=False)
