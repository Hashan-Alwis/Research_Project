# %%
import pandas as pd

# %%
df = pd.read_csv("Reviews.csv", encoding='latin1')

# %%
df.head()
# Out:
#   Location_Name Located_City                      Location Location_Type  \
# 0    Arugam Bay   Arugam Bay  Arugam Bay, Eastern Province       Beaches
# 1    Arugam Bay   Arugam Bay  Arugam Bay, Eastern Province       Beaches
# 2    Arugam Bay   Arugam Bay  Arugam Bay, Eastern Province       Beaches
# 3    Arugam Bay   Arugam Bay  Arugam Bay, Eastern Province       Beaches
# 4    Arugam Bay   Arugam Bay  Arugam Bay, Eastern Province       Beaches
#
#   User_ID           User_Location User_Locale  User_Contributions Travel_Date  \
# 0  User 1  Dunsborough, Australia       en_US                   8      19-Jul
# 1  User 2      Bendigo, Australia       en_US                   4      19-Jun
# 2  User 3    Melbourne, Australia       en_US                  13      19-Jul
# 3  User 4      Ericeira, Portugal       en_US                   4      19-Jun
# 4  User 5          Pistoia, Italy       en_US                  14      19-Jul
#
#               Published_Date  Rating  Helpful_Votes  \
# ...

# %%
len(df["Location_Name"].unique())
# Out:
# 76

# %%
df.columns
# Out:
# Index(['Location_Name', 'Located_City', 'Location', 'Location_Type', 'User_ID',
#        'User_Location', 'User_Locale', 'User_Contributions', 'Travel_Date',
#        'Published_Date', 'Rating', 'Helpful_Votes', 'Title', 'Text'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df['Description_Length'] = df['Text'].str.len()

# %%
result = df.loc[df.groupby('Location_Name')['Description_Length'].idxmin()]

# %%
len(result["Location_Name"].unique())
# Out:
# 76

# %%
df=result.drop(columns=['Description_Length'])

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                     Location_Name  Located_City  \
# 0               Abhayagiri Dagaba  Anuradhapura
# 1                  Ambewela Farms  Nuwara Eliya
# 2           Ariyapala Mask Museum   Ambalangoda
# 3                      Arugam Bay    Arugam Bay
# 4                   Baker's Falls  Nuwara Eliya
# ..                            ...           ...
# 71        Udawalawe National Park  Embilipitiya
# 72         Udawattekele Sanctuary         Kandy
# 73  Victoria Park of Nuwara Eliya  Nuwara Eliya
# 74         Wilpattu National Park    Saliyapura
# 75          World Buddhist Museum         Kandy
#
#                                             Location            Location_Type  \
# 0               Anuradhapura, North Central Province          Religious Sites
# 1                     Nuwara Eliya, Central Province                    Farms
# 2     Ambalangoda, Galle District, Southern Province                  Museums
# ...

# %%
df["Location_Type"].unique()
# Out:
# array(['Religious Sites', 'Farms', 'Museums', 'Beaches', 'Waterfalls',
#        'Gardens', 'National Parks', 'Historic Sites', 'Bodies of Water',
#        'Nature & Wildlife Areas', 'Zoological Gardens'], dtype=object)

# %%
df.to_csv("only_place.csv")
